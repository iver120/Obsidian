# %%
b = input("Skriv ett tall: ")
a = input("Skriv enda ett tall: ")

if a > b: 
    print(a, "er større enn", b)
elif a == b:
    print("Tallene er like store")
elif b > a: 
    print(b, "er større enn", a)
else: 
    print("Her kan du bare skrive tall, den nisse")
# Out:
# Skriv ett tall: 5
# Skriv enda ett tall: hest
# hest er større enn 5
